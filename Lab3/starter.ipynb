# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (24.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install mlflow
# Out:
# Collecting mlflow
#   Downloading mlflow-2.16.1-py3-none-any.whl.metadata (29 kB)
# Collecting mlflow-skinny==2.16.1 (from mlflow)
#   Downloading mlflow_skinny-2.16.1-py3-none-any.whl.metadata (30 kB)
# Collecting Flask<4 (from mlflow)
#   Downloading flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting alembic!=1.10.0,<2 (from mlflow)
#   Downloading alembic-1.13.2-py3-none-any.whl.metadata (7.4 kB)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow)
#   Downloading graphene-3.3-py2.py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: markdown<4,>=3.3 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (3.6)
# Requirement already satisfied: matplotlib<4 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (3.8.0)
# Requirement already satisfied: numpy<3 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (1.26.0)
# Requirement already satisfied: pandas<3 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (2.1.1)
# Collecting pyarrow<18,>=4.0.0 (from mlflow)
#   Downloading pyarrow-17.0.0-cp311-cp311-win_amd64.whl.metadata (3.4 kB)
# Collecting scikit-learn<2 (from mlflow)
#   Downloading scikit_learn-1.5.2-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Collecting scipy<2 (from mlflow)
#   Downloading scipy-1.14.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting sqlalchemy<3,>=1.4.0 (from mlflow)
#   Downloading SQLAlchemy-2.0.35-cp311-cp311-win_amd64.whl.metadata (9.9 kB)
# Requirement already satisfied: Jinja2<4,>=3.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (3.1.2)
# Collecting waitress<4 (from mlflow)
#   Downloading waitress-3.0.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting cachetools<6,>=5.0.0 (from mlflow-skinny==2.16.1->mlflow)
#   Downloading cachetools-5.5.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: click<9,>=7.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.16.1->mlflow) (8.1.7)
# Collecting cloudpickle<4 (from mlflow-skinny==2.16.1->mlflow)
#   Downloading cloudpickle-3.0.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==2.16.1->mlflow)
#   Downloading databricks_sdk-0.32.1-py3-none-any.whl.metadata (37 kB)
# Collecting gitpython<4,>=3.1.9 (from mlflow-skinny==2.16.1->mlflow)
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Collecting importlib-metadata!=4.7.0,<9,>=3.7.0 (from mlflow-skinny==2.16.1->mlflow)
#   Downloading importlib_metadata-8.5.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==2.16.1->mlflow)
#   Downloading opentelemetry_api-1.27.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==2.16.1->mlflow)
#   Downloading opentelemetry_sdk-1.27.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: packaging<25 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.16.1->mlflow) (23.1)
# Requirement already satisfied: protobuf<6,>=3.12.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.16.1->mlflow) (3.20.3)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.16.1->mlflow) (6.0.1)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.16.1->mlflow) (2.31.0)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==2.16.1->mlflow)
#   Downloading sqlparse-0.5.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow)
#   Downloading Mako-1.3.5-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from alembic!=1.10.0,<2->mlflow) (4.8.0)
# Requirement already satisfied: pywin32>=304 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from docker<8,>=4.0.0->mlflow) (306)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from docker<8,>=4.0.0->mlflow) (2.0.5)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from Flask<4->mlflow) (3.0.2)
# Collecting itsdangerous>=2.1.2 (from Flask<4->mlflow)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting blinker>=1.6.2 (from Flask<4->mlflow)
#   Downloading blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_core-3.2.4-py3-none-any.whl.metadata (10 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Collecting aniso8601<10,>=8 (from graphene<4->mlflow)
#   Downloading aniso8601-9.0.1-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from Jinja2<4,>=3.0->mlflow) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<4->mlflow) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<4->mlflow) (0.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<4->mlflow) (4.43.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<4->mlflow) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<4->mlflow) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<4->mlflow) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<4->mlflow) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas<3->mlflow) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas<3->mlflow) (2023.3)
# Collecting joblib>=1.2.0 (from scikit-learn<2->mlflow)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn<2->mlflow)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (2.0.2)
# Requirement already satisfied: colorama in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from click<9,>=7.0->mlflow-skinny==2.16.1->mlflow) (0.4.6)
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.16.1->mlflow)
#   Downloading google_auth-2.34.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython<4,>=3.1.9->mlflow-skinny==2.16.1->mlflow)
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Collecting zipp>=3.20 (from importlib-metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.16.1->mlflow)
#   Downloading zipp-3.20.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting deprecated>=1.2.6 (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.16.1->mlflow)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting importlib-metadata!=4.7.0,<9,>=3.7.0 (from mlflow-skinny==2.16.1->mlflow)
#   Downloading importlib_metadata-8.4.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from importlib-metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.16.1->mlflow) (3.18.1)
# Collecting opentelemetry-semantic-conventions==0.48b0 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.16.1->mlflow)
#   Downloading opentelemetry_semantic_conventions-0.48b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib<4->mlflow) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.16.1->mlflow) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.16.1->mlflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.16.1->mlflow) (2023.7.22)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.16.1->mlflow) (1.16.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.16.1->mlflow)
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.16.1->mlflow)
#   Downloading pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.16.1->mlflow)
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.16.1->mlflow)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Downloading mlflow-2.16.1-py3-none-any.whl (26.7 MB)
#    ---------------------------------------- 0.0/26.7 MB ? eta -:--:--
#    - -------------------------------------- 0.8/26.7 MB 4.8 MB/s eta 0:00:06
#    -- ------------------------------------- 1.8/26.7 MB 4.8 MB/s eta 0:00:06
#    ---- ----------------------------------- 2.9/26.7 MB 4.7 MB/s eta 0:00:06
#    ----- ---------------------------------- 3.7/26.7 MB 4.4 MB/s eta 0:00:06
#    ------- -------------------------------- 4.7/26.7 MB 4.5 MB/s eta 0:00:05
#    -------- ------------------------------- 5.8/26.7 MB 4.6 MB/s eta 0:00:05
#    --------- ------------------------------ 6.3/26.7 MB 4.6 MB/s eta 0:00:05
#    ---------- ----------------------------- 6.8/26.7 MB 4.1 MB/s eta 0:00:05
#    ----------- ---------------------------- 7.9/26.7 MB 4.1 MB/s eta 0:00:05
#    ------------ --------------------------- 8.7/26.7 MB 4.2 MB/s eta 0:00:05
#    -------------- ------------------------- 9.7/26.7 MB 4.3 MB/s eta 0:00:04
#    --------------- ------------------------ 10.5/26.7 MB 4.2 MB/s eta 0:00:04
#    ---------------- ----------------------- 11.3/26.7 MB 4.2 MB/s eta 0:00:04
#    ------------------ --------------------- 12.3/26.7 MB 4.2 MB/s eta 0:00:04
#    -------------------- ------------------- 13.6/26.7 MB 4.3 MB/s eta 0:00:03
#    --------------------- ------------------ 14.4/26.7 MB 4.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 15.5/26.7 MB 4.4 MB/s eta 0:00:03
#    ------------------------ --------------- 16.5/26.7 MB 4.4 MB/s eta 0:00:03
#    -------------------------- ------------- 17.6/26.7 MB 4.4 MB/s eta 0:00:03
#    --------------------------- ------------ 18.6/26.7 MB 4.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 19.4/26.7 MB 4.5 MB/s eta 0:00:02
#    ------------------------------ --------- 20.4/26.7 MB 4.5 MB/s eta 0:00:02
#    -------------------------------- ------- 21.5/26.7 MB 4.5 MB/s eta 0:00:02
#    --------------------------------- ------ 22.3/26.7 MB 4.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 23.3/26.7 MB 4.5 MB/s eta 0:00:01
#    ------------------------------------ --- 24.4/26.7 MB 4.5 MB/s eta 0:00:01
#    -------------------------------------- - 25.4/26.7 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------  26.5/26.7 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------- 26.7/26.7 MB 4.5 MB/s eta 0:00:00
# Downloading mlflow_skinny-2.16.1-py3-none-any.whl (5.6 MB)
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ------- -------------------------------- 1.0/5.6 MB 6.3 MB/s eta 0:00:01
#    -------------- ------------------------- 2.1/5.6 MB 5.6 MB/s eta 0:00:01
#    ------------------------ --------------- 3.4/5.6 MB 5.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.2/5.6 MB 5.5 MB/s eta 0:00:01
#    ------------------------------------- -- 5.2/5.6 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 5.6/5.6 MB 4.9 MB/s eta 0:00:00
# Downloading alembic-1.13.2-py3-none-any.whl (232 kB)
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
# Downloading flask-3.0.3-py3-none-any.whl (101 kB)
# Downloading graphene-3.3-py2.py3-none-any.whl (128 kB)
# Downloading pyarrow-17.0.0-cp311-cp311-win_amd64.whl (25.2 MB)
#    ---------------------------------------- 0.0/25.2 MB ? eta -:--:--
#    - -------------------------------------- 0.8/25.2 MB 5.6 MB/s eta 0:00:05
#    --- ------------------------------------ 2.1/25.2 MB 5.3 MB/s eta 0:00:05
#    ----- ---------------------------------- 3.1/25.2 MB 5.4 MB/s eta 0:00:05
#    ------ --------------------------------- 4.2/25.2 MB 5.2 MB/s eta 0:00:04
#    -------- ------------------------------- 5.2/25.2 MB 5.2 MB/s eta 0:00:04
#    --------- ------------------------------ 6.0/25.2 MB 5.1 MB/s eta 0:00:04
#    ---------- ----------------------------- 6.8/25.2 MB 4.8 MB/s eta 0:00:04
#    ------------ --------------------------- 7.6/25.2 MB 4.6 MB/s eta 0:00:04
#    ------------- -------------------------- 8.4/25.2 MB 4.5 MB/s eta 0:00:04
#    --------------- ------------------------ 9.4/25.2 MB 4.5 MB/s eta 0:00:04
#    ---------------- ----------------------- 10.2/25.2 MB 4.5 MB/s eta 0:00:04
#    ----------------- ---------------------- 11.0/25.2 MB 4.5 MB/s eta 0:00:04
#    ------------------- -------------------- 12.1/25.2 MB 4.4 MB/s eta 0:00:03
#    -------------------- ------------------- 12.8/25.2 MB 4.4 MB/s eta 0:00:03
#    --------------------- ------------------ 13.6/25.2 MB 4.3 MB/s eta 0:00:03
#    ---------------------- ----------------- 14.2/25.2 MB 4.3 MB/s eta 0:00:03
#    ------------------------ --------------- 15.2/25.2 MB 4.2 MB/s eta 0:00:03
#    ------------------------- -------------- 16.0/25.2 MB 4.3 MB/s eta 0:00:03
#    -------------------------- ------------- 16.8/25.2 MB 4.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 17.8/25.2 MB 4.3 MB/s eta 0:00:02
#    ------------------------------ --------- 18.9/25.2 MB 4.3 MB/s eta 0:00:02
#    ------------------------------- -------- 19.7/25.2 MB 4.3 MB/s eta 0:00:02
#    -------------------------------- ------- 20.7/25.2 MB 4.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 21.8/25.2 MB 4.3 MB/s eta 0:00:01
#    ------------------------------------ --- 22.8/25.2 MB 4.3 MB/s eta 0:00:01
#    ------------------------------------- -- 23.9/25.2 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------  24.9/25.2 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 25.2/25.2 MB 4.3 MB/s eta 0:00:00
# Downloading scikit_learn-1.5.2-cp311-cp311-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/11.0 MB 5.6 MB/s eta 0:00:02
#    ------- -------------------------------- 2.1/11.0 MB 5.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.9/11.0 MB 5.2 MB/s eta 0:00:02
#    --------------- ------------------------ 4.2/11.0 MB 5.0 MB/s eta 0:00:02
#    ------------------- -------------------- 5.2/11.0 MB 5.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.3/11.0 MB 5.0 MB/s eta 0:00:01
#    -------------------------- ------------- 7.3/11.0 MB 5.0 MB/s eta 0:00:01
#    ------------------------------ --------- 8.4/11.0 MB 5.1 MB/s eta 0:00:01
#    -------------------------------- ------- 8.9/11.0 MB 4.8 MB/s eta 0:00:01
#    ------------------------------------ --- 10.0/11.0 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.0 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 4.7 MB/s eta 0:00:00
# Downloading scipy-1.14.1-cp311-cp311-win_amd64.whl (44.8 MB)
#    ---------------------------------------- 0.0/44.8 MB ? eta -:--:--
#     --------------------------------------- 0.8/44.8 MB 4.2 MB/s eta 0:00:11
#    - -------------------------------------- 1.8/44.8 MB 4.6 MB/s eta 0:00:10
#    -- ------------------------------------- 2.9/44.8 MB 4.9 MB/s eta 0:00:09
#    --- ------------------------------------ 3.9/44.8 MB 5.0 MB/s eta 0:00:09
#    ---- ----------------------------------- 5.2/44.8 MB 5.1 MB/s eta 0:00:08
#    ----- ---------------------------------- 6.3/44.8 MB 5.0 MB/s eta 0:00:08
#    ------ --------------------------------- 7.3/44.8 MB 5.0 MB/s eta 0:00:08
#    ------- -------------------------------- 8.4/44.8 MB 5.0 MB/s eta 0:00:08
#    -------- ------------------------------- 9.2/44.8 MB 5.0 MB/s eta 0:00:08
#    --------- ------------------------------ 10.2/44.8 MB 4.8 MB/s eta 0:00:08
#    ---------- ----------------------------- 11.3/44.8 MB 4.9 MB/s eta 0:00:07
#    ----------- ---------------------------- 12.6/44.8 MB 5.0 MB/s eta 0:00:07
#    ----------- ---------------------------- 13.4/44.8 MB 4.9 MB/s eta 0:00:07
#    ------------- -------------------------- 14.7/44.8 MB 5.0 MB/s eta 0:00:07
#    -------------- ------------------------- 15.7/44.8 MB 5.0 MB/s eta 0:00:06
#    -------------- ------------------------- 16.8/44.8 MB 5.0 MB/s eta 0:00:06
#    ---------------- ----------------------- 18.1/44.8 MB 5.1 MB/s eta 0:00:06
#    ----------------- ---------------------- 19.1/44.8 MB 5.0 MB/s eta 0:00:06
#    ----------------- ---------------------- 19.4/44.8 MB 5.0 MB/s eta 0:00:06
#    ------------------ --------------------- 20.4/44.8 MB 4.8 MB/s eta 0:00:06
#    ------------------ --------------------- 21.2/44.8 MB 4.8 MB/s eta 0:00:05
#    ------------------- -------------------- 22.3/44.8 MB 4.8 MB/s eta 0:00:05
#    -------------------- ------------------- 23.3/44.8 MB 4.8 MB/s eta 0:00:05
#    --------------------- ------------------ 24.4/44.8 MB 4.8 MB/s eta 0:00:05
#    ---------------------- ----------------- 25.4/44.8 MB 4.8 MB/s eta 0:00:05
#    ----------------------- ---------------- 26.5/44.8 MB 4.8 MB/s eta 0:00:04
#    ------------------------ --------------- 27.3/44.8 MB 4.8 MB/s eta 0:00:04
#    ------------------------- -------------- 28.3/44.8 MB 4.7 MB/s eta 0:00:04
#    ------------------------- -------------- 29.1/44.8 MB 4.7 MB/s eta 0:00:04
#    -------------------------- ------------- 29.9/44.8 MB 4.7 MB/s eta 0:00:04
#    --------------------------- ------------ 30.4/44.8 MB 4.7 MB/s eta 0:00:04
#    ---------------------------- ----------- 31.5/44.8 MB 4.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 32.2/44.8 MB 4.6 MB/s eta 0:00:03
#    ----------------------------- ---------- 33.3/44.8 MB 4.6 MB/s eta 0:00:03
#    ------------------------------ --------- 34.3/44.8 MB 4.6 MB/s eta 0:00:03
#    ------------------------------- -------- 35.4/44.8 MB 4.7 MB/s eta 0:00:03
#    -------------------------------- ------- 36.4/44.8 MB 4.7 MB/s eta 0:00:02
#    --------------------------------- ------ 37.5/44.8 MB 4.7 MB/s eta 0:00:02
#    --------------------------------- ------ 38.0/44.8 MB 4.6 MB/s eta 0:00:02
#    ---------------------------------- ----- 39.1/44.8 MB 4.6 MB/s eta 0:00:02
#    ----------------------------------- ---- 40.1/44.8 MB 4.6 MB/s eta 0:00:02
#    ------------------------------------ --- 41.2/44.8 MB 4.6 MB/s eta 0:00:01
#    ------------------------------------- -- 41.9/44.8 MB 4.6 MB/s eta 0:00:01
#    -------------------------------------- - 43.0/44.8 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  44.0/44.8 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  44.6/44.8 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 44.8/44.8 MB 4.6 MB/s eta 0:00:00
# Downloading SQLAlchemy-2.0.35-cp311-cp311-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    --------------- ------------------------ 0.8/2.1 MB 3.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.8/2.1 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 4.2 MB/s eta 0:00:00
# Downloading waitress-3.0.0-py3-none-any.whl (56 kB)
# Downloading aniso8601-9.0.1-py2.py3-none-any.whl (52 kB)
# Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Downloading cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Downloading cloudpickle-3.0.0-py3-none-any.whl (20 kB)
# Downloading databricks_sdk-0.32.1-py3-none-any.whl (551 kB)
#    ---------------------------------------- 0.0/552.0 kB ? eta -:--:--
#    ---------------------------------------- 552.0/552.0 kB 3.7 MB/s eta 0:00:00
# Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
# Downloading graphql_core-3.2.4-py3-none-any.whl (203 kB)
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading opentelemetry_api-1.27.0-py3-none-any.whl (63 kB)
# Downloading importlib_metadata-8.4.0-py3-none-any.whl (26 kB)
# Downloading opentelemetry_sdk-1.27.0-py3-none-any.whl (110 kB)
# Downloading opentelemetry_semantic_conventions-0.48b0-py3-none-any.whl (149 kB)
# Downloading sqlparse-0.5.1-py3-none-any.whl (44 kB)
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
# Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
# Downloading google_auth-2.34.0-py2.py3-none-any.whl (200 kB)
# Downloading pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
# Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Installing collected packages: aniso8601, waitress, threadpoolctl, sqlparse, sqlalchemy, smmap, scipy, pyasn1, pyarrow, Mako, joblib, itsdangerous, importlib-metadata, graphql-core, deprecated, cloudpickle, cachetools, blinker, scikit-learn, rsa, pyasn1-modules, opentelemetry-api, graphql-relay, gitdb, Flask, docker, alembic, opentelemetry-semantic-conventions, graphene, google-auth, gitpython, opentelemetry-sdk, databricks-sdk, mlflow-skinny, mlflow
# Successfully installed Flask-3.0.3 Mako-1.3.5 alembic-1.13.2 aniso8601-9.0.1 blinker-1.8.2 cachetools-5.5.0 cloudpickle-3.0.0 databricks-sdk-0.32.1 deprecated-1.2.14 docker-7.1.0 gitdb-4.0.11 gitpython-3.1.43 google-auth-2.34.0 graphene-3.3 graphql-core-3.2.4 graphql-relay-3.2.0 importlib-metadata-8.4.0 itsdangerous-2.2.0 joblib-1.4.2 mlflow-2.16.1 mlflow-skinny-2.16.1 opentelemetry-api-1.27.0 opentelemetry-sdk-1.27.0 opentelemetry-semantic-conventions-0.48b0 pyarrow-17.0.0 pyasn1-0.6.1 pyasn1-modules-0.4.1 rsa-4.9 scikit-learn-1.5.2 scipy-1.14.1 smmap-5.0.1 sqlalchemy-2.0.35 sqlparse-0.5.1 threadpoolctl-3.5.0 waitress-3.0.0

# %%
import mlflow

from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes
from sklearn.ensemble import RandomForestRegressor

mlflow.autolog()

db = load_diabetes()
X_train, X_test, y_train, y_test = train_test_split(db.data, db.target)

# Create and train models.
rf = RandomForestRegressor(n_estimators=100, max_depth=6, max_features=3)
rf.fit(X_train, y_train)

# Use the model to make predictions on the test dataset.
predictions = rf.predict(X_test)
# Out:
# 2024/09/16 20:54:14 WARNING mlflow.utils.autologging_utils: MLflow sklearn autologging is known to be compatible with 0.24.1 <= scikit-learn <= 1.5.1, but the installed version is 1.5.2. If you encounter errors during autologging, try upgrading / downgrading scikit-learn to a compatible version, or try upgrading MLflow.
# 2024/09/16 20:54:16 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2024/09/16 20:54:17 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'de446d5c3402443ba3778e02005dafa1', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow

# %%
# !mlflow ui --port=5001

# %%
import mlflow 
from sklearn.model_selection import train_test_split 
from sklearn.datasets import load_diabetes

# set the experiment id
mlflow.set_experiment(experiment_id="0")

mlflow.autolog() 
db = load_diabetes() 

X_train, X_test, y_train, y_test = train_test_split(db.data, db.target) 

# Create and train models. 
rf = RandomForestRegressor(n_estimators=100, max_depth=6, max_features=3) 
rf.fit(X_train, y_train) 

# Use the model to make predictions on the test dataset. 
predictions = rf.predict(X_test)

# %%
# !mlflow ui --port=5001

# %% [markdown]
# ### Store ML models

# %%
import mlflow
from mlflow.models import infer_signature

from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes
from sklearn.ensemble import RandomForestRegressor

with mlflow.start_run() as run:
    # Load the diabetes dataset.
    db = load_diabetes()
    X_train, X_test, y_train, y_test = train_test_split(db.data, db.target)

    # Create and train models.
    rf = RandomForestRegressor(n_estimators=100, max_depth=6, max_features=3)
    rf.fit(X_train, y_train)

    # Use the model to make predictions on the test dataset.
    predictions = rf.predict(X_test)
    print(predictions)

    signature = infer_signature(X_test, predictions)
    mlflow.sklearn.log_model(rf, "model", signature=signature)

    print(f"Run ID: {run.info.run_id}")

# %%
# !mlflow ui --port=5001

# %% [markdown]
# ### Load a model

# %%
import mlflow

from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes

db = load_diabetes()
X_train, X_test, y_train, y_test = train_test_split(db.data, db.target)

model = mlflow.sklearn.load_model("mlruns/0/a7edd2653458481ab60488297d06a781/artifacts/model/")
predictions = model.predict(X_test)
print(predictions)
